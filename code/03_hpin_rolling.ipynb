# %% [markdown]
# # 3. Rolling-window HPIN estimation
#
# Windows of 60–180 periods sliding one period at a time, cold start at every window, out-of-sample one-step-ahead PLS computed at the first out-of-window observation.
#
# Output: `../data/pins/sinteticos/pin_hmm_{w}_{dataset}.csv`.

# %%
import rolling_hpin
for ds in rolling_hpin.DATASETS:
    rolling_hpin.run(ds)
