# %% [markdown]
# # 4. Analysis: metrics, tests, sensitivity, fairness
#
# Requires the classical PIN rolling estimates (`Rscript run_pin_classic.R`, see README) in addition to step 3.
#
# Produces all tables in `../results/tables/` (means, stds, MIV, PACF, half-life with the ρ₁∈(0,1) guard, out-of-sample PLS, transition-derived metrics, paired block-bootstrap Wilcoxon tests, descriptive statistics).

# %%
import compute_metrics
compute_metrics.main()

# %% [markdown]
# ## Initialization sensitivity (Appendix)
#
# 50 randomized starts on the full series and on a representative 60-period window.

# %%
import sensitivity_init
sensitivity_init.main()

# %% [markdown]
# ## Fairness check on the i.i.d. DGP
#
# Γ̂ should collapse to identical rows (spectral gap → 1): the HPIN must not fabricate persistence on memoryless data.

# %%
import fairness_iid
fairness_iid.main()
