# %% [markdown]
# # 1. Synthetic order-flow generation
#
# Generates the three data-generating processes used in the paper (seed 42):
#
# 1. **dynamic** — Markov informational states (η=0.5, κ=0.5, φ±=0.5, ω±=0.1) with a common Inverse Gaussian factor IG(1, 9) scaling both intensities each period (mixed-Poisson emissions);
# 2. **iid** — degenerate transition matrix (rows = stationary distribution of the dynamic Γ): the classical PIN's own DGP, used for the fairness check;
# 3. **clean** — dynamic states without the IG factor: correctly specified Markov–Poisson process, used for the parameter-recovery check.
#
# Output: `../data/fluxos/sinteticos/*.csv` (buyer, seller, true state, Z).

# %%
import generate_series
generate_series.main()
