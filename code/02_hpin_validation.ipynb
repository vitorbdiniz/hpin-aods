# %% [markdown]
# # 2. Estimator validation
#
# Hard gate: on the **clean** DGP the tied Baum–Welch (module `hpin.py`, Algorithm 1 / Appendix A of the paper) must recover the true parameters. Diagnostics on the **dynamic** (IG) DGP illustrate the overdispersion misspecification faced by both models.

# %%
import validate_fit
ok = validate_fit.main()
assert ok, 'recovery gate failed'
